# %%
df_1 = _dntk.execute_sql(
  'SELECT * FROM ANALYTICS.DBT_SCARTIGNY.FCT_NUMBER_OF_FLIGHTS',
  'SQL_DC353D72_A543_4183_A111_9C84400B54EC',
  audit_sql_comment='',
  sql_cache_mode='cache_disabled',
  return_variable_type='dataframe'
)
df_1
# Out:
#   aircraft_type aircraft_id  number_of_flights
# 0         Goose         g72               1008
# 1    Thundercat         t10                553
# 2     Miniflock         12a                277
# 3     Bezantium         b23                240
# 4   Flockinator         12d                192

# %%
_dntk.DeepnoteChart(df_1, """{"layer":[{"layer":[{"layer":[{"mark":{"clip":true,"type":"arc","color":"#2266D3","tooltip":true,"innerRadius":{"expr":"0"},"outerRadius":{"expr":"min(width, height) / 2"}},"encoding":{"color":{"axis":{"grid":false},"sort":null,"type":"nominal","field":"aircraft_type","scale":{"scheme":"deepnote10"}},"order":{"axis":{"grid":false,"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"sort":"descending","type":"quantitative","field":"number_of_flights","scale":{},"stack":true,"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"theta":{"axis":{"grid":false,"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"number_of_flights","scale":{},"stack":true,"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"tooltip":[{"axis":{"grid":false},"sort":null,"type":"nominal","field":"aircraft_type","scale":{"scheme":"deepnote10"}},{"axis":{"grid":false,"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"number_of_flights","scale":{},"stack":true,"format":".0%","aggregate":"sum"}]},"transform":[{"groupby":["aircraft_type"],"aggregate":[{"as":"deepnote_percentage_custom_field_percentage_grouped","op":"sum","field":"number_of_flights"}]},{"frame":[null,null],"window":[{"as":"deepnote_percentage_custom_field_percentage_total","op":"sum","field":"deepnote_percentage_custom_field_percentage_grouped"}]},{"as":"number_of_flights","calculate":"datum['deepnote_percentage_custom_field_percentage_grouped'] / datum['deepnote_percentage_custom_field_percentage_total']"}]},{"mark":{"dx":0,"dy":-1,"fill":{"expr":"valueLabelsColor"},"type":"text","align":"center","radius":{"expr":"min(width, height) / 2 + 30"},"baseline":"bottom"},"encoding":{"text":{"type":"quantitative","field":"number_of_flights","stack":true,"format":".0%","aggregate":"sum"},"color":{"axis":{"grid":false},"sort":null,"type":"nominal","field":"aircraft_type","scale":{"scheme":"deepnote10"}},"order":{"axis":{"grid":false,"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"sort":"descending","type":"quantitative","field":"number_of_flights","scale":{},"stack":true,"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"theta":{"axis":{"grid":false,"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"number_of_flights","scale":{},"stack":true,"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"tooltip":[{"axis":{"grid":false},"sort":null,"type":"nominal","field":"aircraft_type","scale":{"scheme":"deepnote10"}},{"axis":{"grid":false,"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"number_of_flights","scale":{},"stack":true,"format":".0%","aggregate":"sum"}]},"transform":[{"groupby":["aircraft_type"],"aggregate":[{"as":"deepnote_percentage_custom_field_percentage_grouped","op":"sum","field":"number_of_flights"}]},{"frame":[null,null],"window":[{"as":"deepnote_percentage_custom_field_percentage_total","op":"sum","field":"deepnote_percentage_custom_field_percentage_grouped"}]},{"as":"number_of_flights","calculate":"datum['deepnote_percentage_custom_field_percentage_grouped'] / datum['deepnote_percentage_custom_field_percentage_total']"}]}]}],"resolve":{"scale":{"color":"independent"}}}],"title":"Quel avion a le plus volé ?","config":{"legend":{"disable":false}},"params":[{"name":"valueLabelsColor","value":"black"}],"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"seriesNames":["number_of_flights"],"seriesOrder":[0],"specSchemaVersion":2,"tooltipDefaultMode":true}}""", attach_selection=True, filters='[]')

# %%
df_8 = _dntk.execute_sql(
  'SELECT * FROM ANALYTICS.DBT_SCARTIGNY.DIM_AIRCRAFTS',
  'SQL_DC353D72_A543_4183_A111_9C84400B54EC',
  audit_sql_comment='',
  sql_cache_mode='cache_disabled',
  return_variable_type='dataframe'
)
df_8
# Out:
#   aircraft_id aircraft_type     mass  lenght        cost  capacity
# 0         12d   Flockinator  1000000   10000   100000000      1000
# 1         12a     Miniflock    50000    2000     2000000       200
# 2         g72         Goose   200000    5000     3000000       500
# 3         t10    Thundercat  1500000   20000   400000000      2000
# 4         b23     Bezantium  4000000  100000  1000000000      5000

# %%
_dntk.DeepnoteChart(df_8, """{"layer":[{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","tooltip":false},"encoding":{"x":{"sort":null,"type":"nominal","field":"aircraft_type","scale":{"type":"linear"}},"y":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"cost","scale":{"type":"sqrt"},"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"color":{"sort":null,"type":"nominal","field":"aircraft_type","scale":{"scheme":"deepnote10"}},"xOffset":{"sort":null,"type":"nominal","field":"aircraft_type"}},"transform":[]},{"mark":{"dx":0,"dy":-1,"fill":{"expr":"valueLabelsColor"},"type":"text","align":"center","baseline":"bottom"},"encoding":{"x":{"sort":null,"type":"nominal","field":"aircraft_type","scale":{"type":"linear"}},"y":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"cost","scale":{"type":"sqrt"},"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"text":{"type":"quantitative","field":"cost"},"color":{"sort":null,"type":"nominal","field":"aircraft_type","scale":{"scheme":"deepnote10"}},"xOffset":{"sort":null,"type":"nominal","field":"aircraft_type"}},"transform":[]}]}],"resolve":{"scale":{"color":"independent"}}}],"title":"Coût du type d'avion","config":{"legend":{"disable":false}},"params":[{"name":"valueLabelsColor","value":"black"}],"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"seriesNames":["cost"],"seriesOrder":[0],"specSchemaVersion":2,"tooltipDefaultMode":true}}""", attach_selection=True, filters='[]')

# %%
df_2 = _dntk.execute_sql(
  'SELECT * FROM ANALYTICS.DBT_SCARTIGNY.FCT_AIRPORTS',
  'SQL_DC353D72_A543_4183_A111_9C84400B54EC',
  audit_sql_comment='',
  sql_cache_mode='cache_disabled',
  return_variable_type='dataframe'
)
df_2
# Out:
#   airport_code       airport_name  passengers_nb
# 0          FKT         Flocktopia    430959170.0
# 1          NSA   Nestland Airport    179064722.0
# 2          AMP  Amazon Mothership     80033991.0

# %%
_dntk.DeepnoteChart(df_2, """{"layer":[{"layer":[{"layer":[{"mark":{"clip":true,"type":"arc","color":"#2266D3","tooltip":true,"innerRadius":{"expr":"0"},"outerRadius":{"expr":"min(width, height) / 2"}},"encoding":{"color":{"sort":null,"type":"nominal","field":"airport_name","scale":{"scheme":"deepnote10"}},"order":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"sort":"descending","type":"quantitative","field":"passengers_nb","scale":{},"stack":true,"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"theta":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"passengers_nb","scale":{},"stack":true,"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"}},"transform":[]},{"mark":{"dx":0,"dy":-1,"fill":"black","type":"text","align":"center","radius":{"expr":"min(width, height) / 2 + 30"},"baseline":"bottom"},"encoding":{"text":{"type":"quantitative","field":"passengers_nb","stack":true,"aggregate":"sum"},"color":{"sort":null,"type":"nominal","field":"airport_name","scale":{"scheme":"deepnote10"}},"order":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"sort":"descending","type":"quantitative","field":"passengers_nb","scale":{},"stack":true,"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"theta":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"passengers_nb","scale":{},"stack":true,"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"}},"transform":[]}]}],"resolve":{"scale":{"color":"independent"}}}],"title":"Quel aéroport a reçu le plus de passagers ?","config":{"legend":{"disable":false}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"seriesNames":["passengers_nb"],"seriesOrder":[0],"specSchemaVersion":2,"tooltipDefaultMode":true}}""", attach_selection=True, filters='[]')

# %%
df_9 = _dntk.execute_sql(
  'SELECT * FROM ANALYTICS.DBT_SCARTIGNY.DIM_AIRPORTS',
  'SQL_DC353D72_A543_4183_A111_9C84400B54EC',
  audit_sql_comment='',
  sql_cache_mode='cache_disabled',
  return_variable_type='dataframe'
)
df_9
# Out:
#   airport_code       airport_name  airport_employees  airport_size
# 0          FKT         Flocktopia            1000000       2000000
# 1          NSA   Nestland Airport              20000         50000
# 2          AMP  Amazon Mothership             100000         10000

# %%
_dntk.DeepnoteChart(df_9, """{"layer":[{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","tooltip":true},"encoding":{"x":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"airport_employees","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"y":{"sort":null,"type":"nominal","field":"airport_name","scale":{"type":"linear"}},"color":{"sort":null,"type":"nominal","field":"airport_name","scale":{"scheme":"deepnote10"}},"yOffset":{"sort":null,"type":"nominal","field":"airport_name"}},"transform":[]}]}],"resolve":{"scale":{"color":"independent"}}}],"title":"Le nombre d'employés par aéroport","config":{"legend":{"disable":false}},"params":[{"name":"valueLabelsColor","value":"black"}],"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"seriesNames":["airport_employees"],"seriesOrder":[0],"specSchemaVersion":2,"tooltipDefaultMode":true}}""", attach_selection=True, filters='[]')

# %%
df_10 = _dntk.execute_sql(
  'SELECT \n    DIM.airport_name,\n    DIM.airport_code,\n    FCT.passengers_nb,\n    DIM.airport_employees,\n    CAST(FCT.passengers_nb AS REAL) / DIM.airport_employees AS Ratio_Passengers_Par_Employee\n\nFROM \n    ANALYTICS.DBT_SCARTIGNY.FCT_AIRPORTS AS FCT\nINNER JOIN\n    ANALYTICS.DBT_SCARTIGNY.DIM_AIRPORTS AS DIM \nON \n    FCT.AIRPORT_CODE = DIM.AIRPORT_CODE\nORDER BY\n    Ratio_Passengers_Par_Employee DESC',
  'SQL_DC353D72_A543_4183_A111_9C84400B54EC',
  audit_sql_comment='',
  sql_cache_mode='cache_disabled',
  return_variable_type='dataframe'
)
df_10
# Out:
#         airport_name airport_code  passengers_nb  airport_employees  \
# 0   Nestland Airport          NSA    179064722.0              20000
# 1  Amazon Mothership          AMP     80033991.0             100000
# 2         Flocktopia          FKT    430959170.0            1000000
#
#    ratio_passengers_par_employee
# 0                     8953.23610
# 1                      800.33991
# 2                      430.95917

# %%
_dntk.DeepnoteChart(df_10, """{"layer":[{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","tooltip":true},"encoding":{"x":{"sort":null,"type":"nominal","field":"airport_name","scale":{"type":"linear"}},"y":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"ratio_passengers_par_employee","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"color":{"sort":null,"type":"nominal","field":"airport_name","scale":{"scheme":"deepnote10"}},"xOffset":{"sort":null,"type":"nominal","field":"airport_name"}},"transform":[]}]}],"resolve":{"scale":{"color":"independent"}}}],"title":"","config":{"legend":{"disable":false}},"params":[{"name":"valueLabelsColor","value":"black"}],"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"seriesNames":["ratio_passengers_par_employee"],"seriesOrder":[0],"specSchemaVersion":2,"tooltipDefaultMode":true}}""", attach_selection=True, filters='[]')

# %%
df_11 = _dntk.execute_sql(
  'SELECT \n    DIM.airport_name,\n    DIM.airport_code,\n    FCT.passengers_nb,\n    DIM.airport_size,\n    CAST(FCT.passengers_nb AS REAL) / DIM.airport_size AS Ratio_Passengers_Par_Size\n\nFROM \n    ANALYTICS.DBT_SCARTIGNY.FCT_AIRPORTS AS FCT\nINNER JOIN\n    ANALYTICS.DBT_SCARTIGNY.DIM_AIRPORTS AS DIM \nON \n    FCT.AIRPORT_CODE = DIM.AIRPORT_CODE\nORDER BY\n    Ratio_Passengers_Par_Size DESC',
  'SQL_DC353D72_A543_4183_A111_9C84400B54EC',
  audit_sql_comment='',
  sql_cache_mode='cache_disabled',
  return_variable_type='dataframe'
)
df_11
# Out:
#         airport_name airport_code  passengers_nb  airport_size  \
# 0  Amazon Mothership          AMP     80033991.0         10000
# 1   Nestland Airport          NSA    179064722.0         50000
# 2         Flocktopia          FKT    430959170.0       2000000
#
#    ratio_passengers_par_size
# 0                8003.399100
# 1                3581.294440
# 2                 215.479585

# %%
_dntk.DeepnoteChart(df_11, """{"layer":[{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","tooltip":false},"encoding":{"x":{"sort":null,"type":"nominal","field":"airport_name","scale":{"type":"linear"}},"y":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"ratio_passengers_par_size","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"color":{"sort":null,"type":"nominal","field":"airport_name","scale":{"scheme":"deepnote10"}},"xOffset":{"sort":null,"type":"nominal","field":"airport_name"}},"transform":[]}]}],"resolve":{"scale":{"color":"independent"}}}],"title":"","config":{"legend":{"disable":false}},"params":[{"name":"valueLabelsColor","value":"black"}],"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"seriesNames":["ratio_passengers_par_size"],"seriesOrder":[0],"specSchemaVersion":2,"tooltipDefaultMode":true}}""", attach_selection=True, filters='[]')

# %%
df_4 = _dntk.execute_sql(
  'SELECT * FROM ANALYTICS.DBT_SCARTIGNY.FCT_CROISSANCE',
  'SQL_DC353D72_A543_4183_A111_9C84400B54EC',
  audit_sql_comment='',
  sql_cache_mode='cache_disabled',
  return_variable_type='dataframe'
)
df_4
# Out:
#   airline_code     airline_name  best_year  best_taux_croissance
# 0           AA  Amazon Airlines       2012                 46.02
# 1           FA        Flock Air       2016                 16.04
# 2           GA    Goose Airways       2010                 20.67

# %%
df_5 = _dntk.execute_sql(
  'SELECT * FROM ANALYTICS.DBT_SCARTIGNY.FCT_CROISSANCE_YEAR',
  'SQL_DC353D72_A543_4183_A111_9C84400B54EC',
  audit_sql_comment='',
  sql_cache_mode='cache_disabled',
  return_variable_type='dataframe'
)
df_5
# Out:
#    airline_code     airline_name  year  avg_asm_domestic  previous_year  \
# 0            AA  Amazon Airlines  2002      3.159310e+05            NaN
# 1            AA  Amazon Airlines  2003      2.956455e+05   3.159310e+05
# 2            AA  Amazon Airlines  2004      2.966414e+05   2.956455e+05
# 3            AA  Amazon Airlines  2005      2.552891e+05   2.966414e+05
# 4            AA  Amazon Airlines  2006      2.707884e+05   2.552891e+05
# 5            AA  Amazon Airlines  2007      2.541191e+05   2.707884e+05
# 6            AA  Amazon Airlines  2008      2.320213e+05   2.541191e+05
# 7            AA  Amazon Airlines  2009      2.090256e+05   2.320213e+05
# 8            AA  Amazon Airlines  2010      2.120457e+05   2.090256e+05
# 9            AA  Amazon Airlines  2011      1.944707e+05   2.120457e+05
# 10           AA  Amazon Airlines  2012      2.839749e+05   1.944707e+05
# 11           AA  Amazon Airlines  2013      2.895528e+05   2.839749e+05
# ...

# %%
_dntk.DeepnoteChart(df_5, """{"layer":[{"layer":[{"layer":[{"mark":{"clip":true,"type":"line","tooltip":true},"encoding":{"x":{"axis":{"grid":false},"sort":"ascending","type":"temporal","field":"year","scale":{"type":"linear","zero":false},"bandPosition":0},"y":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"taux_croissance","scale":{"type":"linear","zero":false},"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"color":{"sort":null,"type":"nominal","field":"airline_name","scale":{"scheme":"deepnote10"}}},"transform":[]}]}],"resolve":{"scale":{"color":"independent"}}}],"title":"Le taux de croissance des compagnies aériennes ","config":{"legend":{"disable":false}},"params":[{"name":"valueLabelsColor","value":"black"}],"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"seriesNames":["taux_croissance"],"seriesOrder":[0],"specSchemaVersion":2,"tooltipDefaultMode":true}}""", attach_selection=True, filters='[]')

# %%
df_6 = _dntk.execute_sql(
  'SELECT * FROM ANALYTICS.DBT_SCARTIGNY.FCT_AIRLINES',
  'SQL_DC353D72_A543_4183_A111_9C84400B54EC',
  audit_sql_comment='',
  sql_cache_mode='cache_disabled',
  return_variable_type='dataframe'
)
df_6
# Out:
#   airline_code     airline_name  year  total_revenue              metrique
# 0           AA  Amazon Airlines  2015      9175044.0     Revenu Domestique
# 1           FA        Flock Air  2016     13405774.0     Revenu Domestique
# 2           GA    Goose Airways  2016     34637841.0     Revenu Domestique
# 3           AA  Amazon Airlines  2016      2792855.0  Revenu International
# 4           FA        Flock Air  2016      3912894.0  Revenu International
# 5           GA    Goose Airways  2015     15219579.0  Revenu International
# 6           AA  Amazon Airlines  2015     11912594.0          Revenu Total
# 7           FA        Flock Air  2016     17318668.0          Revenu Total
# 8           GA    Goose Airways  2016     49260222.0          Revenu Total

# %%
_dntk.DeepnoteChart(df_6, """{"layer":[{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","tooltip":true},"encoding":{"x":{"sort":null,"type":"nominal","field":"airline_name","scale":{"type":"linear"}},"y":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"total_revenue","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"color":{"sort":null,"type":"nominal","field":"metrique","scale":{"scheme":"deepnote10"}},"xOffset":{"sort":null,"type":"nominal","field":"metrique"}},"transform":[]}]}],"resolve":{"scale":{"color":"independent"}}}],"title":"Revenus des compagnies aériennes sur l'année 2016","config":{"legend":{"disable":false}},"params":[{"name":"valueLabelsColor","value":"black"}],"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"seriesNames":["total_revenue"],"seriesOrder":[0],"specSchemaVersion":2,"tooltipDefaultMode":true}}""", attach_selection=True, filters='[]')

# %%
df_7 = _dntk.execute_sql(
  'SELECT * FROM ANALYTICS.DBT_SCARTIGNY.FCT_AIRLINES_RPM_YEAR',
  'SQL_DC353D72_A543_4183_A111_9C84400B54EC',
  audit_sql_comment='',
  sql_cache_mode='cache_disabled',
  return_variable_type='dataframe'
)
df_7
# Out:
#     year airline_code     airline_name  domestic_revenue  \
# 0   2002           FA        Flock Air           2230661
# 1   2003           FA        Flock Air           9261591
# 2   2004           FA        Flock Air          10423626
# 3   2005           FA        Flock Air          10933508
# 4   2006           FA        Flock Air          11038142
# 5   2007           FA        Flock Air          11008565
# 6   2009           FA        Flock Air           9594278
# 7   2010           FA        Flock Air           9593913
# 8   2012           FA        Flock Air           9949351
# 9   2014           FA        Flock Air           9730918
# 10  2016           FA        Flock Air          13405774
# 11  2003           GA    Goose Airways          23752966
# 12  2004           GA    Goose Airways          26060600
# 13  2005           GA    Goose Airways          27070798
# 14  2009           GA    Goose Airways          22402772
# ...

# %%
_dntk.DeepnoteChart(df_7, """{"layer":[{"layer":[{"layer":[{"mark":{"clip":true,"type":"line","tooltip":true},"encoding":{"x":{"axis":{"grid":false},"sort":null,"type":"temporal","field":"year","scale":{"type":"linear","zero":false},"bandPosition":0},"y":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"total_revenue","scale":{"type":"linear","zero":false},"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"color":{"sort":null,"type":"nominal","field":"airline_name","scale":{"scheme":"deepnote10"}}},"transform":[]}]}],"resolve":{"scale":{"color":"independent"}}}],"title":"","config":{"legend":{"disable":false}},"params":[{"name":"valueLabelsColor","value":"black"}],"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"seriesNames":["total_revenue"],"seriesOrder":[0],"specSchemaVersion":2,"tooltipDefaultMode":true}}""", attach_selection=True, filters='[]')
